# %%
from utils.compression_compare import *
import matplotlib.pyplot as plt
plt.rcParams["font.family"] = "serif"
plt.rcParams['font.size'] = 13

# %% [markdown]
# ### Tiny Imagenet Dataset

# %%
tiny_jpeg_bpp = [0.27, 0.38, 0.6, 0.94, 1.40, 2.77]
tiny_bls_bpp = [0.257, 0.6, 0.859, 1.206, 1.596, 1.744 ]
tiny_bmhj_bpp = [0.22, 0.6, 0.93, 1.38, 1.99, 2.18, 2.64]

cifar_bls_bpp = [0.26, 0.52, 0.69, 1.08, 1.49, 1.63, 1.91]
cifar_jpeg_bpp = [0.36, 0.48, 0.75, 1.0, 1.50, 1.91]

# %%
data_folder_tiny = "/media/expansion1/navneedhmaudgalya/Datasets/tiny_imagenet"
data_folder_cifar = "/media/expansion1/navneedhmaudgalya/Datasets/cifar"

# %% [markdown]
# ### JPEG Compression

# %%
data_folder = data_folder_tiny 

test = data_folder + "/train"
jpeg_1 = data_folder + "/train_jpeg_1"
jpeg_5 = data_folder + "/train_jpeg_5"
jpeg_10 = data_folder + "/train_jpeg_10"
jpeg_20 = data_folder + "/train_jpeg_20"
jpeg_40 = data_folder + "/train_jpeg_40"
jpeg_60 = data_folder + "/train_jpeg_60"

jpeg_1_psnr = get_metrics(test, jpeg_1, "psnr")
jpeg_5_psnr = get_metrics(test, jpeg_5, "psnr")
jpeg_10_psnr = get_metrics(test, jpeg_10, "psnr")
jpeg_20_psnr = get_metrics(test, jpeg_20, "psnr")
jpeg_40_psnr = get_metrics(test, jpeg_40, "psnr")
jpeg_60_psnr = get_metrics(test, jpeg_60, "psnr")

jpeg_1_ssim = get_metrics(test, jpeg_1, "ssim")
jpeg_5_ssim = get_metrics(test, jpeg_5, "ssim")
jpeg_10_ssim = get_metrics(test, jpeg_10, "ssim")
jpeg_20_ssim = get_metrics(test, jpeg_20, "ssim")
jpeg_40_ssim = get_metrics(test, jpeg_40, "ssim")
jpeg_60_ssim = get_metrics(test, jpeg_60, "ssim")

all_jpeg_ssim = [jpeg_1_ssim, jpeg_5_ssim, jpeg_10_ssim, jpeg_20_ssim, jpeg_40_ssim, jpeg_60_ssim]
all_jpeg_psnr = [jpeg_1_psnr, jpeg_5_psnr, jpeg_10_psnr, jpeg_20_psnr, jpeg_40_psnr, jpeg_60_psnr]
# Out:
# ...
# 100%|██████████| 10000/10000 [00:21<00:00, 463.39it/s]

# %%
data_folder = data_folder_cifar

test = data_folder + "/test"
jpeg_1_cifar = data_folder + "/test_jpeg_1"
jpeg_5_cifar = data_folder + "/test_jpeg_5"
jpeg_10_cifar = data_folder + "/test_jpeg_10"
jpeg_20_cifar = data_folder + "/test_jpeg_20"
jpeg_40_cifar = data_folder + "/test_jpeg_40"
jpeg_60_cifar = data_folder + "/test_jpeg_60"

jpeg_1_psnr_cifar = get_metrics(test, jpeg_1_cifar, "psnr")
jpeg_5_psnr_cifar = get_metrics(test, jpeg_5_cifar, "psnr")
jpeg_10_psnr_cifar = get_metrics(test, jpeg_10_cifar, "psnr")
jpeg_20_psnr_cifar = get_metrics(test, jpeg_20_cifar, "psnr")
jpeg_40_psnr_cifar = get_metrics(test, jpeg_40_cifar, "psnr")
jpeg_60_psnr_cifar = get_metrics(test, jpeg_60_cifar, "psnr")

jpeg_1_ssim_cifar = get_metrics(test, jpeg_1_cifar, "ssim")
jpeg_5_ssim_cifar = get_metrics(test, jpeg_5_cifar, "ssim")
jpeg_10_ssim_cifar = get_metrics(test, jpeg_10_cifar, "ssim")
jpeg_20_ssim_cifar = get_metrics(test, jpeg_20_cifar, "ssim")
jpeg_40_ssim_cifar = get_metrics(test, jpeg_40_cifar, "ssim")
jpeg_60_ssim_cifar = get_metrics(test, jpeg_60_cifar, "ssim")

cifar_jpeg_ssim = [jpeg_1_ssim_cifar, jpeg_5_ssim_cifar, jpeg_10_ssim_cifar, jpeg_20_ssim_cifar, jpeg_40_ssim_cifar, jpeg_60_ssim_cifar]
cifar_jpeg_psnr = [jpeg_1_psnr_cifar, jpeg_5_psnr_cifar, jpeg_10_psnr_cifar, jpeg_20_psnr_cifar, jpeg_40_psnr_cifar, jpeg_60_psnr_cifar]
# Out:
# ...
# 100%|██████████| 10000/10000 [00:13<00:00, 722.40it/s]

# %%
data_folder = data_folder_tiny
test = data_folder + "/train"
b_001 = data_folder + "/train_bmshj_001n" 
b_003 = data_folder + "/train_bmshj_003n"
b_005 = data_folder + "/train_bmshj_005"
b_012 = data_folder + "/train_bmshj_012n"
b_033 = data_folder + "/train_bmshj_033n"
b_05 = data_folder + "/train_bmshj_05n"

b_001_ssim = get_metrics(test, b_001, "ssim")
b_003_ssim = get_metrics(test, b_003, "ssim")
b_005_ssim = get_metrics(test, b_005, "ssim")
b_012_ssim = get_metrics(test, b_012, "ssim")
b_033_ssim = get_metrics(test, b_033, "ssim")
b_05_ssim = get_metrics(test, b_05, "ssim")
# b_1_ssim = get_metrics(test, b_1, "ssim")

b_001_psnr = get_metrics(test, b_001, "psnr")
b_003_psnr = get_metrics(test, b_003, "psnr")
b_005_psnr = get_metrics(test, b_005, "psnr")
b_012_psnr = get_metrics(test, b_012, "psnr")
b_033_psnr = get_metrics(test, b_033, "psnr")
b_05_psnr = get_metrics(test, b_05, "psnr")
# b_1_ssim = get_metrics(test, b_1, "ssim")



all_b_ssim = [b_001_ssim, b_003_ssim, b_005_ssim, b_012_ssim, b_033_ssim, b_05_ssim]
all_b_psnr = [b_001_psnr, b_003_psnr, b_005_psnr, b_012_psnr, b_033_psnr, b_05_psnr]
# Out:
# ...
# 100%|██████████| 10000/10000 [00:08<00:00, 1200.50it/s]

# %%
data_folder = data_folder_cifar

test = data_folder + "/test"
b_001_cifar = data_folder + "/test_bls_001"
b_003_cifar = data_folder + "/test_bls_003"
b_005_cifar = data_folder + "/test_bls_005"
b_012_cifar = data_folder + "/test_bls_012"
b_033_cifar = data_folder + "/test_bls_033"
b_05_cifar = data_folder + "/test_bls_05"
b_1_cifar = data_folder + "/test_bls_1"

b_001_ssim_cifar = get_metrics(test, b_001_cifar, "ssim")
b_003_ssim_cifar = get_metrics(test, b_003_cifar, "ssim")
b_005_ssim_cifar = get_metrics(test, b_005_cifar, "ssim")
b_012_ssim_cifar = get_metrics(test, b_012_cifar, "ssim")
b_033_ssim_cifar = get_metrics(test, b_033_cifar, "ssim")
b_05_ssim_cifar = get_metrics(test, b_05_cifar, "ssim")
b_1_ssim_cifar = get_metrics(test, b_1_cifar, "ssim")

b_001_psnr_cifar = get_metrics(test, b_001_cifar, "psnr")
b_003_psnr_cifar = get_metrics(test, b_003_cifar, "psnr")
b_005_psnr_cifar = get_metrics(test, b_005_cifar, "psnr")
b_012_psnr_cifar = get_metrics(test, b_012_cifar, "psnr")
b_033_psnr_cifar = get_metrics(test, b_033_cifar, "psnr")
b_05_psnr_cifar = get_metrics(test, b_05_cifar, "psnr")
b_1_psnr_cifar = get_metrics(test, b_1_cifar, "psnr")



cifar_b_ssim = [b_001_ssim_cifar, b_003_ssim_cifar, b_005_ssim_cifar, b_012_ssim_cifar, b_033_ssim_cifar, b_05_ssim_cifar, b_1_ssim_cifar]
cifar_b_psnr = [b_001_psnr_cifar, b_003_psnr_cifar, b_005_psnr_cifar, b_012_psnr_cifar, b_033_psnr_cifar, b_05_psnr_cifar, b_1_psnr_cifar]
# Out:
# ...
# 100%|██████████| 10000/10000 [00:04<00:00, 2158.76it/s]

# %%
fig, axs = plt.subplots(2,2,figsize=(10,8), sharey = "row", sharex = "col")

bmjh_means_ssim = [np.mean(np.array(data)) for data in cifar_b_ssim]
bmjh_stds = [np.std(np.array(data)) for data in cifar_b_ssim]
axs[0,0].errorbar(cifar_bls_bpp, bmjh_means_ssim, bmjh_stds, color = "orange", label = "BLS")

jpeg_means_ssim = [np.mean(np.array(data)) for data in cifar_jpeg_ssim]
jpeg_stds = [np.std(np.array(data)) for data in cifar_jpeg_ssim]
axs[0,0].errorbar(cifar_jpeg_bpp, jpeg_means_ssim, jpeg_stds,  color = "blue", label = "JPEG")


bmjh_means = [np.mean(np.array(data)) for data in cifar_b_psnr]
bmjh_stds = [np.std(np.array(data)) for data in cifar_b_psnr]
axs[1,0].errorbar(cifar_bls_bpp, bmjh_means, bmjh_stds, color = "orange", label = "BLS")

print(bmjh_means)

jpeg_means = [np.mean(np.array(data)) for data in cifar_jpeg_psnr]
jpeg_stds = [np.std(np.array(data)) for data in cifar_jpeg_psnr]
axs[1,0].errorbar(cifar_jpeg_bpp, jpeg_means, jpeg_stds, color = "blue", label = "JPEG")

print(jpeg_means)

bmjh_means_ssim = [np.mean(np.array(data)) for data in all_b_ssim]
bmjh_stds = [np.std(np.array(data)) for data in all_b_ssim]
axs[0,1].errorbar(tiny_bmhj_bpp[:-1], bmjh_means_ssim, bmjh_stds,color = "green", label = "BMJH")

jpeg_means_ssim = [np.mean(np.array(data)) for data in all_jpeg_ssim]
jpeg_stds = [np.std(np.array(data)) for data in all_jpeg_ssim]
axs[0,1].errorbar(tiny_jpeg_bpp, jpeg_means_ssim, jpeg_stds, color = "blue", label = "JPEG")


bmjh_means = [np.mean(np.array(data)) for data in all_b_psnr]
bmjh_stds = [np.std(np.array(data)) for data in all_b_psnr]
axs[1,1].errorbar(tiny_bmhj_bpp[:-1], bmjh_means, bmjh_stds, color = "green", label = "BMJH")

print(bmjh_means)

jpeg_means = [np.mean(np.array(data)) for data in all_jpeg_psnr]
jpeg_stds = [np.std(np.array(data)) for data in all_jpeg_psnr]
axs[1,1].errorbar(tiny_jpeg_bpp, jpeg_means, jpeg_stds, color = "blue", label = "JPEG")

print(jpeg_means)

axs[0,0].grid()
axs[0,1].grid()
axs[1,0].grid()
axs[1,1].grid()
axs[1,0].legend(loc = 4)

axs[1,1].legend(loc = 4)
axs[1,0].set_xlabel("Average Bit Rate (bpp) \n CIFAR-10")
axs[1,1].set_xlabel("Average Bit Rate (bpp) \n Tiny ImageNet")
axs[1,0].set_ylabel("PSNR [dB]")
axs[0,0].set_ylabel("SSIM")
plt.subplots_adjust(left=0.1,
                    bottom=0.1, 
                    right=0.9, 
                    top=0.9, 
                    wspace=0.01, 
                    hspace=0.01)
plt.savefig("ssim.png")
# Out:
# [70.79729360853239, 73.4946560640531, 74.79034571820387, 76.68966325217183, 77.74087980823379, 78.09331479772197, 78.36313089528345]
# [66.77749201889438, 69.00128812822874, 71.41538589853432, 73.63346919222693, 75.70015984217537, 77.05283569886534]
# [68.98837607384726, 71.80515044220253, 72.85641815928662, 75.10832200050257, 76.79166597111572, 77.59989025150645]
# [66.06938907747407, 67.63509148568933, 69.3024102572235, 70.91857720844554, 72.83737544130572, 77.38812423494146]

# %%
bmjh_means
# Out:
# [68.98837607384726,
#  71.80515044220253,
#  72.85641815928662,
#  75.10832200050257,
#  76.79166597111572,
#  77.59989025150645]

# %%
bmjh_means_ssim
# Out:
# [0.6558833653233284,
#  0.8178349294995872,
#  0.8660676283868756,
#  0.9201470542674022,
#  0.9476130723121283,
#  0.9579273307945654]

# %% [markdown]
# ### Cifar Dataset

# %%
# Out:
# ...
# 100%|██████████| 10000/10000 [00:13<00:00, 721.65it/s]

# %%
bls_001 = data_folder + "/test_bls_001"
bls_003 = data_folder + "/test_bls_003"
bls_005 = data_folder + "/test_bls_005"
bls_012 = data_folder + "/test_bls_012"
bls_033 = data_folder + "/test_bls_033"
bls_05 = data_folder + "/test_bls_05"
bls_1 = data_folder + "/test_bls_1"

bls_001_res = get_metrics(test, bls_001, metric)
bls_003_res = get_metrics(test, bls_003, metric)
bls_005_res = get_metrics(test, bls_005, metric)
bls_012_res = get_metrics(test, bls_012, metric)
bls_033_res = get_metrics(test, bls_033, metric)
bls_05_res = get_metrics(test, bls_05, metric)
bls_1_res = get_metrics(test, bls_1, metric)
# Out:
# ...
# 100%|██████████| 10000/10000 [00:15<00:00, 655.30it/s]

# %%
cifar_bls_res = [bls_001_res, bls_003_res, bls_005_res, bls_012_res, bls_033_res, bls_05_res, bls_1_res]
cifar_jpeg_res = [jpeg_1_res, jpeg_5_res, jpeg_10_res, jpeg_20_res, jpeg_40_res, jpeg_60_res]
bls_bpp = [0.26, 0.52, 0.69, 1.08, 1.49, 1.63, 1.91]
jpeg_bpp = [0.36, 0.48, 0.75, 1.0, 1.50, 1.91]

# %%
bls_means = [np.mean(np.array(data)) for data in cifar_bls_res]
bls_means

# %%
print(get_bpp(bls_033).mean())

plt.xlabel("Bits Per Pixel (BPP) of Test Data")
plt.ylabel("SSIM")
bls_means = [np.mean(np.array(data)) for data in cifar_bls_res]
bls_stds = [np.std(np.array(data)) for data in cifar_bls_res]
plt.errorbar(bls_bpp, bls_means, bls_stds, label = "BLS", color = "orange")

jpeg_means = [np.mean(np.array(data)) for data in cifar_jpeg_res]
jpeg_stds = [np.std(np.array(data)) for data in cifar_jpeg_res]
plt.errorbar(jpeg_bpp, jpeg_means, jpeg_stds, label = "JPEG", color = "green")
plt.legend(loc = 4)
# plt.savefig("ssim.png", dpi = 100)
# Out:
# 1.4871266

# %%
jpeg_means
# Out:
# [0.6282734028726298,
#  0.7544690408452686,
#  0.8414159296752199,
#  0.8952277393712936,
#  0.9293016265473689,
#  0.9455897175998793]
